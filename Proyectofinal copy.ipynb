# %%
import numpy as np
import sklearn
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
#    # INFO DATABASE:
#
#
# Citation Request:
#   This dataset is public available for research. The details are described in [Moro et al., 2011].
#   Please include this citation if you plan to use this database:
#
#   [Moro et al., 2011] S. Moro, R. Laureano and P. Cortez. Using Data Mining for Bank Direct Marketing: An Application of the CRISP-DM Methodology.
#   In P. Novais et al. (Eds.), Proceedings of the European Simulation and Modelling Conference - ESM'2011, pp. 117-121, Guimarães, Portugal, October, 2011. EUROSIS.
#
#   Available at: [pdf] http://hdl.handle.net/1822/14838
#                 [bib] http://www3.dsi.uminho.pt/pcortez/bib/2011-esm-1.txt
#
# 1. Title: Bank Marketing
#
# 2. Sources
#    Created by: Paulo Cortez (Univ. Minho) and Sérgio Moro (ISCTE-IUL) @ 2012
#
# 3. Past Usage:
#
#   The full dataset was described and analyzed in:
#
#   S. Moro, R. Laureano and P. Cortez. Using Data Mining for Bank Direct Marketing: An Application of the CRISP-DM Methodology.
#   In P. Novais et al. (Eds.), Proceedings of the European Simulation and Modelling Conference - ESM'2011, pp. 117-121, Guimarães,
#   Portugal, October, 2011. EUROSIS.
#
# 4. Relevant Information:
#
#    The data is related with direct marketing campaigns of a Portuguese banking institution.
#    The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required,
#    in order to access if the product (bank term deposit) would be (or not) subscribed.
#
#    There are two datasets:
#       1) bank-full.csv with all examples, ordered by date (from May 2008 to November 2010).
#       2) bank.csv with 10% of the examples (4521), randomly selected from bank-full.csv.
#    The smallest dataset is provided to test more computationally demanding machine learning algorithms (e.g. SVM).
#
#    The classification goal is to predict if the client will subscribe a term deposit (variable y).
#
# 5. Number of Instances: 45211 for bank-full.csv (4521 for bank.csv)
#
# 6. Number of Attributes: 16 + output attribute.
#
# 7. Attribute information:
#
#    For more information, read [Moro et al., 2011].
#
#    Input variables:
#
# 8. Missing Attribute Values: None
#
#    # bank client data:
#    1 - age (numeric)
#
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student","blue-collar","self-employed","retired","technician","services")
#
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#
#    5 - default: has credit in default? (binary: "yes","no")
#
#    6 - balance: average yearly balance, in euros (numeric)
#
#    7 - housing: has housing loan? (binary: "yes","no")
#
#    8 - loan: has personal loan? (binary: "yes","no")
#    # related with the last contact of the current campaign:
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#
#    10 - day: last contact day of the month (numeric)
#
#    11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#
#    12 - duration: last contact duration, in seconds (numeric)
#    # other attributes:
#    13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
#    14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
#    15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
#    16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#   Output variable (desired target):
#
#    17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
#
# The aim of EUROSIS (The European Multidisciplinary Society for Modelling and Simulation Technology) is to be the primary mover and initiator for and of European simulation and modelling projects, which bridge the gap between academic and industry based simulation and modelling research in Europe.

# %%
#Import the files
bank=pd.read_csv('../bank/bank.csv',sep=';')
bank_full=pd.read_csv('../bank/bank-full.csv',sep=';')
data_add_full=pd.read_csv('../bank/bank-additional-full.csv',sep=';')
data_add=pd.read_csv('../bank/bank-additional.csv',sep=';')

# %% [markdown]
# # DATA EXPLORATION

# %% [markdown]
# ##### I decide to use the both database, the first one have the balance and the  other euribor and other ecnomic features.

# %%
#bank.head()
#bank_full[:5]
#data_add_full[:5]
#data_add[:5]
print(data_add_full.columns)
print(bank_full.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
#bank.info()
#bank_full.info()
#data_add_full.info()
#data_add.info()
data=bank_full
print(bank_full.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
def explore_data(df):
    # this function applies many exploratory techniques to a given a overview of the dataframe
    display("Head",
            df.head()
            .style
            .background_gradient(cmap='Blues')
           )
    display("Data Types",
            df.dtypes
            .to_frame()
           )
    display("Data Types Count",
            df.dtypes
            .to_frame()[0]
            .value_counts()
            .to_frame()
           )
    display("Nan Values per Column",
            df.isna()
            .sum()
            .to_frame()
            .sort_values(by=[0], ascending=False)
           )
    display("Descriptive Statistics",
            df.describe()
           )
    display("Correlation Matrix",
            df.corr()
            .style.background_gradient(cmap='coolwarm')
            .set_precision(2)
           )
    
#explore_data(data)

# %%
 def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

missing_values_table(data)
# Out:
# Your selected dataframe has 17 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# # Exploratory Analysis:
#
# #### The data is clean, then let's visualize:
#
#
# 1. Balance
#
# 2. Age
#
# 3. Job VS Education
#
# 4. Marital
#
# 5. Default
#
# 6. Deposit (Y)
#
# 7. Loans (Personal loans and housing)
#
# 8. Correlation
#
# 9. Conclusions

# %% [markdown]
# ### 1. Balance

# %%
data["balance"].hist(bins=100)

# %%
round(data.pivot_table(columns='marital',aggfunc={'balance': np.mean}),0)#index='job', 
round(data.pivot_table(columns='education',aggfunc={'balance': np.mean}),0)
#round(data.pivot_table(columns='job',aggfunc={'balance': np.mean}),0)
#round(data.pivot_table(columns='loan',aggfunc={'balance': np.mean}),0)
#round(data.pivot_table(columns='housing',aggfunc={'balance': np.mean}),0)
#round(data.pivot_table(columns='default',aggfunc={'balance': np.mean}),0)
# Out:
# education  primary  secondary  tertiary  unknown
# balance     1251.0     1155.0    1758.0   1527.0

# %%
data["balance"].quantile(0.80)
# Out:
# 1859.0

# %%
data[(data.balance >= 1859)]["age"].median()
# Out:
# 42.0

# %% [markdown]
# ### 2. Age

# %%
fig, ax = plt.subplots(figsize=(15,15))  
sns.countplot(y='age', data=data)

# %%
import seaborn as sns

sns.violinplot("age", data = data)
sns.distplot(data['age'])

# %%
sns.boxplot(data["age"])

# %%
round(data.pivot_table( columns='age',aggfunc={'balance': np.mean}),0)#index='age',
# Out:
# age         18     19     20     21     22      23     24     25      26  \
# balance  372.0  540.0  842.0  867.0  936.0  1040.0  915.0  871.0  1035.0
#
# age          27  ...      85      86      87     88     89     90     92  \
# balance  1084.0  ...  4603.0  1315.0  2400.0  540.0  625.0  356.0  775.0
#
# age         93      94      95
# balance  775.0  1234.0  1141.0
#
# [1 rows x 77 columns]

# %%
# cuanta gente hay entre 80 y 85 y 85 y 90??
#data[data.groupby(['balance'])['age']>85]
data[(data.age >= 70) & (data.age <= 80)].count()  # count 455  /mean age  74.193407 / balance     2884.751648
#data[(data.age >= 80) & (data.age <= 85)].mean()# =====> count 103  / balance     3590.097087
#data[(data.age >= 85)].mean()#===>  count 32/ balance     1710.50000
# Out:
# age          455
# job          455
# marital      455
# education    455
# default      455
# balance      455
# housing      455
# loan         455
# contact      455
# day          455
# month        455
# duration     455
# campaign     455
# pdays        455
# previous     455
# poutcome     455
# y            455
# dtype: int64

# %%
ig, axs = plt.subplots(nrows=1, ncols=1,figsize=(20, 10))
sns.lineplot(x="age", y="balance", data=data)
axs.set_xlabel('AGE')
axs.set_ylabel('BALANCE')
# Out:
# Text(0, 0.5, 'BALANCE')

# %% [raw]
# data.groupby(["age"]).count()

# %%
#neg from 25 to 60, that is when the people get retired
fig, ax = plt.subplots(figsize=(15,15))  
plt.scatter(data["balance"], data["age"], label="Year built")

# %%
data['job'][data['age']>60].value_counts()
# Out:
# retired          875
# management       105
# housemaid         56
# technician        30
# blue-collar       26
# admin.            25
# self-employed     24
# unknown           22
# entrepreneur      13
# unemployed        10
# services           2
# Name: job, dtype: int64

# %%
data['job'][data['age']>60].value_counts().sum()/len(data)*100
# Out:
# 2.6276791046426755

# %%
#top client
data.sort_values("balance", axis = 0, ascending = False).head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 39989   51  management   single   tertiary      no   102127      no   no
# 26227   59  management  married   tertiary      no    98417      no   no
# 43393   84     retired  married  secondary      no    81204      no   no
# 42558   84     retired  married  secondary      no    81204      no   no
# 41693   60     retired  married    primary      no    71188      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 39989   cellular    3   jun        90         1     -1         0  unknown   no
# 26227  telephone   20   nov       145         5     -1         0  unknown   no
# 43393  telephone    1   apr       390         1     94         3  success  yes
# 42558  telephone   28   dec       679         1    313         2    other  yes
# 41693   cellular    6   oct       205         1     -1         0  unknown   no

# %%
#I will drop the 1% richer because outliers
data["balance"].quantile(0.95)
# Out:
# 5768.0

# %%
clients95 = data[~(data['balance'] >= data["balance"].quantile(0.95))]  
clients95.max()
# Out:
# age               95
# job          unknown
# marital       single
# education    unknown
# default          yes
# balance         5766
# housing          yes
# loan             yes
# contact      unknown
# day               31
# month            sep
# duration        3881
# campaign          58
# pdays            871
# previous         275
# poutcome     unknown
# y                yes
# dtype: object

# %%
ig, axs = plt.subplots(nrows=1, ncols=1,figsize=(20, 10))
sns.lineplot(x="age", y="balance", data=clients99)
axs.set_xlabel('AGE')
axs.set_ylabel('BALANCE')
# Out:
# Text(0, 0.5, 'BALANCE')

# %%
ig, axs = plt.subplots(nrows=1, ncols=1,figsize=(20, 10))
sns.lineplot(x="age", y="balance", data=clients95)
axs.set_xlabel('AGE')
axs.set_ylabel('BALANCE')
# Out:
# Text(0, 0.5, 'BALANCE')

# %% [markdown]
# ## 3. Job VS Education

# %%
x=round(datas.pivot_table( columns='job',aggfunc={'balance': np.mean}),0).T
x.sort_values("balance", axis = 0)
# Out:
#                balance
# job
# services         997.0
# blue-collar     1079.0
# admin.          1136.0
# technician      1253.0
# student         1388.0
# housemaid       1392.0
# entrepreneur    1521.0
# unemployed      1522.0
# self-employed   1648.0
# management      1764.0
# unknown         1772.0
# retired         1984.0

# %%
#Can be related with the age???

x=round(datas.pivot_table( columns='education',aggfunc={'balance': np.mean}),0).T
x.sort_values("balance", axis = 0)
# Out:
#            balance
# education
# secondary   1155.0
# primary     1251.0
# unknown     1527.0
# tertiary    1758.0

# %%
job_edu=round(data.pivot_table(index='education', columns='job',aggfunc={'balance': np.mean}),0)
job_edu
# Out:
#           balance                                                        \
# job        admin. blue-collar entrepreneur housemaid management retired
# education
# primary     930.0      1086.0       1679.0    1128.0     1672.0  1880.0
# secondary  1116.0      1064.0       1071.0    1444.0     1327.0  2061.0
# tertiary   1218.0      1549.0       1832.0    1830.0     1834.0  2161.0
# unknown    1601.0      1041.0       1554.0    2939.0     1635.0  1503.0
#
#
# job       self-employed services student technician unemployed unknown
# education
# primary          1331.0    967.0  1244.0     1487.0     1588.0  1750.0
# secondary        1287.0    958.0  1260.0     1125.0     1433.0  1250.0
# tertiary         1951.0   1211.0  1645.0     1511.0     1687.0  2359.0
# unknown          1569.0   1683.0  1475.0     1758.0     1522.0  1893.0

# %%
sns.countplot(y='job', data=data)

# %%
sns.countplot(y='education', data=data)

# %%
fig, axs = plt.subplots(nrows=1, ncols=1,figsize=(20, 10))
sns.lineplot(x="job", y="balance", data=datass)
axs.set_xlabel('JOB')
axs.set_ylabel('BALANCE')
# Out:
# Text(0, 0.5, 'BALANCE')

# %% [markdown]
# ## 4. Married VS Single

# %%
fig, axs = plt.subplots(nrows=1, ncols=1,figsize=(7, 8))
plt.scatter(data['marital'],data['balance'])
axs.set_xlabel('marital')
axs.set_ylabel('balance')
# Out:
# Text(0, 0.5, 'balance')

# %%
fig, axs = plt.subplots(nrows=1, ncols=1,figsize=(20, 10))
sns.lineplot(x="marital", y="balance", data=datass)
axs.set_xlabel('MARITAL')
axs.set_ylabel('BALANCE')
# Out:
# Text(0, 0.5, 'BALANCE')

# %%
count = data.groupby('marital').size()
percent = count/len(data)*100
print(percent)
# Out:
# marital
# divorced    11.517109
# married     60.193316
# single      28.289576
# dtype: float64

# %%
round(data.pivot_table( columns='marital',aggfunc={'balance': np.mean}),0)#index='education',
# Out:
# marital  divorced  married  single
# balance    1179.0   1426.0  1301.0

# %%
data.groupby('marital')['age'].median()
# Out:
# marital
# divorced    45
# married     42
# single      32
# Name: age, dtype: int64

# %%
pd.crosstab(data["marital"], columns=0)
# Out:
# col_0         0
# marital
# divorced   5207
# married   27214
# single    12790

# %% [markdown]
# ## 5. Default

# %% [markdown]
# When the client pay or not them loans:

# %%
data.groupby(['default']).mean()
# Out:
#                age      balance        day    duration  campaign      pdays  \
# default
# no       40.961934  1389.806424  15.795792  258.512749  2.756780  40.604536
# yes      39.534969  -137.624540  16.385276  239.115337  3.148466  18.042945
#
#          previous
# default
# no       0.586044
# yes      0.268712

# %%
len(data['balance'][data['default']=='yes'])/#.value_counts().sum()/len(data)*100
# Out:
# 815

# %%
yes=data[data['default']=='yes']

len(yes[yes['balance']<0])
# Out:
# 440

# %%
len(yes[yes['balance']<0])/len(data['balance'][data['default']=='yes'])*100
# Out:
# 53.987730061349694

# %%
sns.countplot(y='default', data=data)

count = data.groupby('default').size()
percent = count/len(data)*100
print(percent)
# Out:
# default
# no     98.197341
# yes     1.802659
# dtype: float64

# %% [markdown]
# ## 6. Deposit (y)

# %% [markdown]
# If the client subscribed a term deposit

# %%
sns.countplot(y='y', data=data)#deposit
data.groupby(['y']).mean()
#round(data.pivot_table( columns='y',aggfunc={'balance': np.mean}),0)
# Out:
#            age      balance        day    duration  campaign      pdays  \
# y
# no   40.838986  1303.714969  15.892290  221.182806  2.846350  36.421372
# yes  41.670070  1804.267915  15.158253  537.294574  2.141047  68.702968
#
#      previous
# y
# no   0.502154
# yes  1.170354

# %% [markdown]
# ## 7. Loan

# %% [markdown]
# How there is personal loans and house loan, I will put the both in one column.  0 -> None,   1 -> one Loan,     2 -> the both loans

# %%
datas=pd.get_dummies(data,columns=['default','y','loan','housing'],drop_first=True)
datas['loan'] =datas['loan_yes']+datas['housing_yes']
datas=datas.drop(['housing_yes','loan_yes','contact','day','month','duration','campaign','pdays','previous','poutcome'], axis=1)

# %%
#how have loan have less money
balance_loan=round(datas.pivot_table(index='loan', columns='job',aggfunc={'balance': np.mean}),0)
balance_loan
# Out:
#      balance                                                        \
# job   admin. blue-collar entrepreneur housemaid management retired
# loan
# 0     1549.0      1531.0       2051.0    1592.0     2046.0  2357.0
# 1     1000.0       990.0       1313.0    1100.0     1614.0  1158.0
# 2      707.0       733.0       1133.0     989.0     1027.0  1094.0
#
#
# job  self-employed services student technician unemployed unknown
# loan
# 0           2112.0   1128.0  1462.0     1384.0     1812.0  1795.0
# 1           1333.0   1020.0  1166.0     1272.0     1243.0  1653.0
# 2            875.0    625.0  2865.0      682.0      563.0   341.0

# %%
datas.pivot_table(index='age', columns=['loan'],aggfunc={'balance': np.mean}).corr()
# Out:
#                balance
# loan                 0         1         2
#         loan
# balance 0     1.000000  0.361514  0.386384
#         1     0.361514  1.000000  0.606752
#         2     0.386384  0.606752  1.000000

# %%
sns.countplot(y='loan', data=datas)
datas.groupby(['loan']).mean()
# Out:
#             age      balance  default_yes     y_yes      jobs    prueba  \
# loan
# 0     43.260695  1737.606719     0.012323  0.182225  5.361195  4.903395
# 1     39.541455  1195.107910     0.019882  0.079907  3.757995  3.985025
# 2     39.329059   788.537898     0.030456  0.060682  3.509274  4.039615
#
#       educations
# loan
# 0       1.340386
# 1       0.994332
# 2       0.893520

# %% [markdown]
# ### 8. CORRELATION

# %% [markdown]
# For can see all the varables, we will have to put in numbers:

# %%
datascorr=pd.get_dummies(datas,columns=['education','job','marital'],drop_first=True)

# %%
datascorr.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col5 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col8 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col9 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col10 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col11 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col12 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col13 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col14 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col15 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col16 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col17 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col19 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col20 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col21 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col22 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row0_col23 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col3 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col4 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col5 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col7 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col8 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col9 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col11 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col12 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col13 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col14 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col15 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col16 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col17 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col18 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col19 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col20 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col21 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col22 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row1_col23 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col6 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col7 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col8 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col9 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col10 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_f264657c_20d8_11ea_acdd_d0a637eccb51row2_col11 {
#             background-color:  #b1cbfc;

# %%
datas['jobs'] = datas['job'].map({'services': 0, 'blue-collar': 1,'admin.': 2, 'technician': 3,'student': 4,'housemaid': 5, 'entrepreneur': 6,'unemployed': 7, 'self-employed': 8,'management':9,'unknown': 10, 'retired': 11})

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
datas["prueba"] = lb_make.fit_transform(datas["job"])
datas[['prueba','jobs']].head()
# Out:
#    prueba  jobs
# 0       4     9
# 1       9     3
# 2       2     6
# 3       1     1
# 4      11    10

# %%
y=round(datas.pivot_table( columns='education',aggfunc={'balance': np.mean}),0).T
y.sort_values("balance", axis = 0)
# Out:
#            balance
# education
# secondary   1155.0
# primary     1251.0
# unknown     1527.0
# tertiary    1758.0

# %%
datas['educations'] = datas['education'].map({'secondary': 0, 'primary': 1,'unknown': 2, 'tertiary': 3})

# %%
dataa=datas.drop(['job','education'], axis=1)

# %%
data_numbers=pd.get_dummies(dataa,columns=['marital'],drop_first=True)
data_numbers.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col2 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col4 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col5 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col8 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row0_col9 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col3 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col4 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col8 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row1_col9 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col5 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col6 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col8 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row2_col9 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col0 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col6 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col7 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col8 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row3_col9 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col0 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col8 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row4_col9 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col0 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col1 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col2 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col6 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col7 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col8 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_f4ea3d58_20d8_11ea_acdd_d0a637eccb51row5_col9 {
#             background-color:  #c6d6f1;
#             color:  #000000;

# %%
data_numbers.corr().style.background_gradient(cmap='Greys').set_precision(5)
# Out:
# <style  type="text/css" >
#     #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col1 {
#             background-color:  #e6e6e6;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col2 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col3 {
#             background-color:  #ececec;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col4 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col5 {
#             background-color:  #bebebe;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col6 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col7 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col8 {
#             background-color:  #7b7b7b;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row0_col9 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col0 {
#             background-color:  #bebebe;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col3 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col4 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col5 {
#             background-color:  #d8d8d8;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col6 {
#             background-color:  #f0f0f0;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col7 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col8 {
#             background-color:  #a5a5a5;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row1_col9 {
#             background-color:  #adadad;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col0 {
#             background-color:  #d1d1d1;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col1 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col3 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col4 {
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col5 {
#             background-color:  #e8e8e8;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col6 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col7 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col8 {
#             background-color:  #adadad;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row2_col9 {
#             background-color:  #a9a9a9;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col0 {
#             background-color:  #cacaca;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col1 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col2 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col4 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col5 {
#             background-color:  #dadada;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col6 {
#             background-color:  #ededed;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col7 {
#             background-color:  #e8e8e8;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col8 {
#             background-color:  #b5b5b5;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row3_col9 {
#             background-color:  #9f9f9f;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col0 {
#             background-color:  #e4e4e4;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col1 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col2 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col3 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col5 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col7 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col8 {
#             background-color:  #a4a4a4;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row4_col9 {
#             background-color:  #b3b3b3;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col0 {
#             background-color:  #9f9f9f;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col1 {
#             background-color:  #e5e5e5;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col2 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col3 {
#             background-color:  #e1e1e1;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col4 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col6 {
#             background-color:  #d6d6d6;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col7 {
#             background-color:  #828282;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col8 {
#             background-color:  #aaaaaa;
#             color:  #000000;
#         }    #T_f5a5ce92_20d8_11ea_acdd_d0a637eccb51row5_col9 {
#             background-color:  #afafaf;
#             color:  #000000;

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style

sns.set(style="white")
corr = data_numbers.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
fig, ax = plt.subplots(figsize=(10,10))   
sns.heatmap(data_numbers.corr())

# %% [markdown]
# ### 9. Conclusions:
#
#
# - The balance
# The pareto theory, 20% richer is when have more 1859 eurosin the account, the people usually invest/spend the money in spite of keep it in the account, the median of have more than 1859 is 42.
# - Age
# 20-60 years, more only
# - Education
# If you want to have money in your account, better have studies.
# - Age
# The big part of the clients are between 20 and 60 years, more than 60 is only the 2.6%.
# - Jobs
# Best are retired, manager, sel-employ and unemployed
# - Maritat
# Married>single>divorced 60% Married and 10% divorced
# - Loans
# richer and older dont have loans
# 53 of people with loans is in red numers

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# Although the exact implementation details can vary, the general structure of a machine learning project stays relatively constant:
#
# - Data cleaning and formatting
#
# - Exploratory data analysis
#
# - Feature engineering and selection
#
# - Establish a baseline and compare several machine learning models on a performance metric
#
# - Perform hyperparameter tuning on the best model to optimize it for the problem
#
# - Evaluate the best model on the testing set
#
# - Interpret the model results to the extent possible
#
# - Draw conclusions and write a well-documented report

# %%
##I have to balance, outliers, 
#Como preparar datos para aplicar modelos??
#colliner? imbalanced? regresion VS clasification?? clean outliers ??? reshape?? ===> aplicar todo


# Scale the model before splitting it as train & test
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
bank_num_scale = scaler.fit_transform(bank_num)


count = data.groupby('default').size()
percent = count/len(data)*100
print(percent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-574-cf47d7ba6e99> in <module>
#       7 from sklearn.preprocessing import StandardScaler
#       8 scaler = StandardScaler()
# ----> 9 bank_num_scale = scaler.fit_transform(bank_num)
#      10
#      11
#
# NameError: name 'bank_num' is not defined

# %% [markdown]
# ### Train and Test split

# %% [markdown]
# Split Into Training and Testing Sets
# In machine learning, we always need to separate our features into two sets:
#
# 1. Training set which we provide to our model during training along with the answers so it can learn a mapping between the features and the target.
#
#
# 2. Testing set which we use to evaluate the mapping learned by the model. The model has never seen the answers on the testing set, but instead, must make predictions using only the features. As we know the true answers for the test set, we can then compare the test predictions to the true test targets to ghet an estimate of how well our model will perform when deployed in the real world.

# %%
y=data_numbers.default_yes

# %%
X=data_numbers.drop(['default_yes'],axis=1)

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=0) #80/20 split

# %%
x_train.shape, y_train.shape
# Out:
# ((36168, 9), (36168,))

# %%
x_test.shape, y_test.shape
# Out:
# ((9043, 9), (9043,))

# %%
# Function to calculate mean absolute error
def mae(y_true, y_pred):
    return np.mean(abs(y_true - y_pred))

# %%
baseline_guess = np.median(y)

print('The baseline guess is a score of %0.2f' % baseline_guess)
print("Baseline Performance on the test set: MAE = %0.4f" % mae(y_test, baseline_guess))
# Out:
# The baseline guess is a score of 0.00
# Baseline Performance on the test set: MAE = 0.0175

# %% [markdown]
# ### Training the model

# %% [markdown]
# #### Logistic Regression

# %%
model=LogisticRegression(penalty='l2', max_iter=1000)

# %%
model.fit(x_train, y_train)
# Out:
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.9824173393785248

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, prediction)
print(confusion_matrix)
# Out:
# [[8880    5]
#  [ 154    4]]

# %%
#plotting ROC curve and getting AUC value
metrics.roc_auc_score(y_test, pred)
# Out:
# 0.506216564683758

# %%
# Getting classification report
print(metrics.classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      8885
#            1       0.50      0.01      0.02       158
#
#     accuracy                           0.98      9043
#    macro avg       0.74      0.51      0.51      9043
# weighted avg       0.97      0.98      0.97      9043

# %%
# Hyper parameter tuning by using grid search cv
#importing modules
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
#making the instance
model=LogisticRegression()
#Hyper Parameters Set
params = {'C': [1,2,3,4,5,6,7], 
          'penalty': ['l1','l2']}
#Making models with hyper parameters sets
model1 = GridSearchCV(model, param_grid=params, n_jobs=-1)
#Learning
model1.fit(x_train,y_train)
#The best hyper parameters set
print("Best Hyper Parameters:\n",model1.best_params_)
#Prediction
prediction=model1.predict(x_test)
#importing the metrics module
from sklearn import metrics
#evaluation(Accuracy)
print("Accuracy:",metrics.accuracy_score(prediction,y_test))
#evaluation(Confusion Metrix)
print("Confusion Metrix:\n",metrics.confusion_matrix(prediction,y_test))
# Out:
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Best Hyper Parameters:
#  {'C': 4, 'penalty': 'l2'}
# Accuracy: 0.9823067566073206
# Confusion Metrix:
#  [[8879  154]
#  [   6    4]]
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
clf = SVC()

# %%
clf.fit(x_train, y_train)
# Out:
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.9825279221497291

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, pred)
print(confusion_matrix)
# Out:
# [[8883    2]
#  [ 156    2]]

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predict = rfc.predict(x_test)

# %%
accuracy_score(y_test, predict)
# Out:
# 0.9810903461240739

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, predict)
print(confusion_matrix)
# Out:
# [[8864   21]
#  [ 150    8]]

# %% [markdown]
# #### Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(10, input_dim=14, activation='tanh'))

model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From /Users/Estelle/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
x_train_keras = np.array(x_train)
y_train_keras = np.array(y_train)
#print(x_train_keras.shape)
y_train_keras = y_train_keras.reshape(y_train_keras.shape[0], 1)

# %%
#model.fit(np.array(x_train_keras), np,.array(y_train_keras), epochs=10, batch_size=128, shuffle=True

# %%
scores = model.evaluate(np.array(x_test), np.array(y_test))

# %%
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
data_numbers.head()
# Out:
#    age  balance  default_yes  y_yes  loan  jobs  prueba  educations  \
# 0   58     2143            0      0     1     9       4           3
# 1   44       29            0      0     1     3       9           0
# 2   33        2            0      0     2     6       2           0
# 3   47     1506            0      0     1     1       1           2
# 4   33        1            0      0     0    10      11           2
#
#    marital_married  marital_single
# 0                1               0
# 1                0               1
# 2                1               0
# 3                1               0
# 4                0               1

# %% [markdown]
# # Regresion
#
# linear regresion o polinomial???

# %% [markdown]
# ## Linear regresion
# For predict the age and balance

# %%
##RESUMEN DE LABS


from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()



from sklearn.metrics import confusion_matrix
y_pred = lr.predict(X_test)
print(confusion_matrix(y_test, y_pred))
acc = lr.score(X_test,y_test)*100 
acc

# %%
# store the feature matrix (X) and response vector (y) 
X = data.drop(['age'],axis=1)
y = data.age

# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_lrr, X_test_lrr, y_train_lrr, y_test_lrr = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn import LinearRegression
x = linear_model.LinearRegresion()
x.fit(X_train_lrr, y_train_lrr) 

# making predictions on the testing set 
y_pred_lrr = x.predict(X_test_lrr) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("LinearRegression model accuracy(in %):", metrics.accuracy_score(y_test_lrr, y_pred_lrr)*100)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-581-e4bc6d490cdc> in <module>
#       8
#       9 # training the model on training set
# ---> 10 from sklearn import LinearRegression
#      11 x = linear_model.LinearRegresion()
#      12 x.fit(X_train_lrr, y_train_lrr)
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn' (/Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/__init__.py)

# %% [markdown]
# ## SVR

# %%
# store the feature matrix (X) and response vector (y) 
X = data_numbers.drop(['balance'],axis=1)
y = data_numbers.balance

# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_svr, X_test_svr, y_train_svr, y_test_svr = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.svm import SVR
x = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
x.fit(X_train_svr, y_train_svr) 

# making predictions on the testing set 
y_pred_svr = x.predict(X_test_svr) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("LinearRegression model accuracy(in %):", metrics.accuracy_score(y_test_svr, y_pred_svr)*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-584-1e6ce8ee0a2b> in <module>
#      17 # comparing actual response values (y_test) with predicted response values (y_pred)
#      18 from sklearn import metrics
# ---> 19 print("LinearRegression model accuracy(in %):", metrics.accuracy_score(y_test_svr, y_pred_svr)*100)
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %%
from scipy.sparse import coo_matrix
X_sparse = coo_matrix(X)

# %% [markdown]
# Accuracy score is only for classification problems. For regression problems you can use: R2 Score, MSE (Mean Squared Error), RMSE (Root Mean Squared Error).

# %% [markdown]
# # INFO DATABASE 2:

# %% [markdown]
# ### Data inputs
# 1.age (numeric)
#
# 2.job : type of job (categorical: “admin”, “blue-collar”, “entrepreneur”, “housemaid”, “management”, “retired”, “self-employed”, “services”, “student”, “technician”, “unemployed”, “unknown”)
#
# 3.marital : marital status (categorical: “divorced”, “married”, “single”, “unknown”)
#
# 4.education (categorical: “basic.4y”, “basic.6y”, “basic.9y”, “high.school”, “illiterate”, “professional.course”, “university.degree”, “unknown”)
#
# 5.default: has credit in default? (categorical: “no”, “yes”, “unknown”)
#
# 6.housing: has housing loan? (categorical: “no”, “yes”, “unknown”)
#
# 7.loan: has personal loan? (categorical: “no”, “yes”, “unknown”)
#
# 8.contact: contact communication type (categorical: “cellular”, “telephone”)
#
# 9.month: last contact month of year (categorical: “jan”, “feb”, “mar”, …, “nov”, “dec”)
#
# 10.day_of_week: last contact day of the week (categorical: “mon”, “tue”, “wed”, “thu”, “fri”)
#
# 11.duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y=’no’). The duration is not known before a call is performed, also, after the end of the call, y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model
#
# 12.campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 13.pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# 14.previous: number of contacts performed before this campaign and for this client (numeric)
#
# 15.poutcome: outcome of the previous marketing campaign (categorical: “failure”, “nonexistent”, “success”)
#
# 16.emp.var.rate: employment variation rate — (numeric)
#
# 17.cons.price.idx: consumer price index — (numeric)
#
# 18.cons.conf.idx: consumer confidence index — (numeric)
#
# 19.euribor3m: euribor 3 month rate — (numeric)
#
# 20.nr.employed: number of employees — (numeric)
#
# ### Target Variable
# y — has the client subscribed a term deposit? (binary: “1”, means “Yes”, “0” means “No”)

# %%
data2=data_add_full

# %%
data2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
def explore_data(df):
    # this function applies many exploratory techniques to a given a overview of the dataframe
    display("Head",
            df.head()
            .style
            .background_gradient(cmap='Blues')
           )
    display("Data Types",
            df.dtypes
            .to_frame()
           )
    display("Data Types Count",
            df.dtypes
            .to_frame()[0]
            .value_counts()
            .to_frame()
           )
    display("Nan Values per Column",
            df.isna()
            .sum()
            .to_frame()
            .sort_values(by=[0], ascending=False)
           )
    display("Descriptive Statistics",
            df.describe()
           )
    display("Correlation Matrix",
            df.corr()
            .style.background_gradient(cmap='coolwarm')
            .set_precision(2)
           )
    
#explore_data(data2)

# %%
#df['y'] = df['y'].map({'no':0, 'yes':1}) # binary encoding of class label
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
data2['y']=lb_make.fit_transform(data2["y"])
data2['job']=lb_make.fit_transform(data2["job"])
data2['marital']=lb_make.fit_transform(data2["marital"])
data2['education']=lb_make.fit_transform(data2["education"])
data2['default']=lb_make.fit_transform(data2["default"])
data2['housing']=lb_make.fit_transform(data2["housing"])
data2['loan']=lb_make.fit_transform(data2["loan"])
data2['contact']=lb_make.fit_transform(data2["contact"])
data2['month']=lb_make.fit_transform(data2["month"])
data2['day_of_week']=lb_make.fit_transform(data2["day_of_week"])
data2['poutcome']=lb_make.fit_transform(data2["poutcome"])

# %%
round(data.pivot_table(index='education', columns='job',aggfunc={'balance': np.mean}),0)
# Out:
#           balance                                                        \
# job        admin. blue-collar entrepreneur housemaid management retired
# education
# primary     930.0      1086.0       1679.0    1128.0     1672.0  1880.0
# secondary  1116.0      1064.0       1071.0    1444.0     1327.0  2061.0
# tertiary   1218.0      1549.0       1832.0    1830.0     1834.0  2161.0
# unknown    1601.0      1041.0       1554.0    2939.0     1635.0  1503.0
#
#
# job       self-employed services student technician unemployed unknown
# education
# primary          1331.0    967.0  1244.0     1487.0     1588.0  1750.0
# secondary        1287.0    958.0  1260.0     1125.0     1433.0  1250.0
# tertiary         1951.0   1211.0  1645.0     1511.0     1687.0  2359.0
# unknown          1569.0   1683.0  1475.0     1758.0     1522.0  1893.0

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data2.info()

data2.corr().style.background_gradient(cmap='Greys').set_precision(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null int64
# marital           41188 non-null int64
# education         41188 non-null int64
# default           41188 non-null int64
# housing           41188 non-null int64
# loan              41188 non-null int64
# contact           41188 non-null int64
# month             41188 non-null int64
# day_of_week       41188 non-null int64
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null int64
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null int64
# dtypes: float64(5), int64(16)
# memory usage: 6.6 MB
# <style  type="text/css" >
#     #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col1 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col3 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col4 {
#             background-color:  #cfcfcf;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col5 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col7 {
#             background-color:  #e6e6e6;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col8 {
#             background-color:  #e9e9e9;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col9 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col10 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col11 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col12 {
#             background-color:  #c3c3c3;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col13 {
#             background-color:  #bababa;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col14 {
#             background-color:  #c6c6c6;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col15 {
#             background-color:  #cfcfcf;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col16 {
#             background-color:  #e8e8e8;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col17 {
#             background-color:  #e2e2e2;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col18 {
#             background-color:  #cacaca;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col19 {
#             background-color:  #c9c9c9;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row0_col20 {
#             background-color:  #d2d2d2;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col0 {
#             background-color:  #d2d2d2;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col2 {
#             background-color:  #cecece;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col3 {
#             background-color:  #d4d4d4;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col4 {
#             background-color:  #eeeeee;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col5 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col7 {
#             background-color:  #ebebeb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col8 {
#             background-color:  #ebebeb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col9 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col10 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col11 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col12 {
#             background-color:  #c2c2c2;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col13 {
#             background-color:  #bababa;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col14 {
#             background-color:  #c7c7c7;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col15 {
#             background-color:  #d0d0d0;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col16 {
#             background-color:  #ebebeb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col17 {
#             background-color:  #efefef;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col18 {
#             background-color:  #cccccc;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col19 {
#             background-color:  #c9c9c9;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row1_col20 {
#             background-color:  #d3d3d3;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col1 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col3 {
#             background-color:  #dadada;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col4 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col5 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col6 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col7 {
#             background-color:  #efefef;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col8 {
#             background-color:  #e7e7e7;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col9 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col10 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col11 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col12 {
#             background-color:  #c4c4c4;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col13 {
#             background-color:  #b8b8b8;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col14 {
#             background-color:  #c9c9c9;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col15 {
#             background-color:  #dcdcdc;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col16 {
#             background-color:  #f1f1f1;
#             color:  #000000;
#         }    #T_4dddef32_1ffc_11ea_acdd_d0a637eccb51row2_col17 {
#             background-color:  #f9f9f9;

# %% [markdown]
# ## Visualizing the Data

# %%
data2.hist(figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a20619a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa12474240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa1253c780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa124d5cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa1250a668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1a7a1048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a190729e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a190a9400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a190a9438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1910c748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a191c7128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a191f2ac8>]],
#       dtype=object)

# %%
sns.countplot(y='job', data=data2)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null int64
# marital           41188 non-null int64
# education         41188 non-null int64
# default           41188 non-null int64
# housing           41188 non-null int64
# loan              41188 non-null int64
# contact           41188 non-null int64
# month             41188 non-null int64
# day_of_week       41188 non-null int64
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null int64
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null int64
# dtypes: float64(5), int64(16)
# memory usage: 6.6 MB

# %%
# visualize categorical features
categorical = ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']
for i in categorical:
    data2[i].value_counts().plot(kind='bar',figsize = (10, 6),title=i)
    plt.show()

# %%
data2['y'].value_counts() # dataset is imbalanced with majority of class label as "no".
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64

# %% [markdown]
# # Machine learning database 2

# %% [markdown]
# How y is for a clasification variable, I want to use next models:
#
#     - LogisticRegression
#     - GaussianNB
#     - Kneighboors Clasifier
#     - SVC
#     - Decision tree
#     - Randomforest

# %% [markdown]
# We select the colummn where is asked "has the client subscribed a term deposit?"

# %%
y =data2.y
X=data2.drop(['y'],axis=1)
X.shape ,y.shape
# Out:
# ((41188, 20), (41188,))

# %%
#So imabalanced data

count = data2.groupby('y').size()
percent = count/len(data2)*100
print(percent)
# Out:
# y
# 0    88.734583
# 1    11.265417
# dtype: float64

# %% [markdown]
# ### Hyperparameter Search

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, precision_recall_curve, auc, roc_auc_score, roc_curve, recall_score, classification_report

parameters = {'C': np.linspace(1,0,2)}
lr = LogisticRegression()
clf = GridSearchCV(lr, parameters, cv=5)#, verbose=5, n_jobs=3)
clf.fit(X_train, y_train.ravel())
# Out:
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:528: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-322-a247fef4a1c7> in <module>
#       6 lr = LogisticRegression()
#       7 clf = GridSearchCV(lr, parameters, cv=5)#, verbose=5, n_jobs=3)
# ----> 8 clf.fit(X_train, y_train.ravel())
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     512             estimator.fit(X_train, **fit_params)
#     513         else:
# --> 514             estimator.fit(X_train, y_train, **fit_params)
#     515
#     516     except Exception as e:
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1547                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1548                 self.max_iter, self.tol, self.random_state,
# -> 1549                 sample_weight=sample_weight)
#    1550             self.n_iter_ = np.array([n_iter_])
#    1551             return self
#
# /Users/Estelle/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     919         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     920         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 921         epsilon, sample_weight)
#     922     # Regarding rnd.randint(..) in the above signature:
#     923     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# sklearn/svm/liblinear.pyx in sklearn.svm.liblinear.train_wrap()
#
# ValueError: b'C <= 0'

# %%
clf.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-316-9772bec5683a> in <module>
# ----> 1 clf.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %% [markdown]
# ## LogisticRegression

# %%
# store the feature matrix (X) and response vector (y) 
#X = data2.drop(['y'],axis=1)
#y = data2.y 

# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.linear_model import LogisticRegression
x = LogisticRegression()#C=7,penalty='l2', verbose=5,solver="lbfgs",max_iter=150)
x.fit(X_train_lr, y_train_lr) 

# making predictions on the testing set 
y_pred_lr = x.predict(X_test_lr) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("LogisticRegression model accuracy(in %):", metrics.accuracy_score(y_test_lr, y_pred_lr)*100)

# %%
print(classification_report(y_test_lr,y_pred_lr))

# %% [markdown]
# ## ROC

# %%
y_pred_sample_score = lr1.decision_function(X_test)


fpr, tpr, thresholds = roc_curve(y_test, y_pred_sample_score)

roc_auc = auc(fpr,tpr)

# Plot ROC
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',label='AUC = %0.3f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.0])
plt.ylim([-0.1,1.01])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
roc_auc
# Out:
# 0.9272208185341818

# %%
print(classification_report(y_test,y_pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10969
#            1       0.66      0.40      0.50      1388
#
#     accuracy                           0.91     12357
#    macro avg       0.79      0.69      0.72     12357
# weighted avg       0.90      0.91      0.90     12357

# %%
cnf_matrix
# Out:
# array([[10682,   287],
#        [  832,   556]])

# %% [markdown]
# ## GaussianNB

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_nb, X_test_nb, y_train_nb, y_test_nb = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train_nb, y_train_nb) 

# making predictions on the testing set 
y_pred_nb = gnb.predict(X_test_nb) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test_nb, y_pred_nb)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 84.86890021849963

# %%
print(classification_report(y_test_nb,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91     14601
#            1       0.39      0.60      0.48      1875
#
#     accuracy                           0.85     16476
#    macro avg       0.67      0.74      0.69     16476
# weighted avg       0.88      0.85      0.86     16476

# %%
#confusion_matrix(y_test_nb, y_pred_nb)

# %% [markdown]
# ## Kneighboors Clasifier

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_kc, X_test_kc, y_train_kc, y_test_kc = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.neighbors import KNeighborsClassifier
x = KNeighborsClassifier() 
x.fit(X_train_kc, y_train_kc) 

# making predictions on the testing set 
y_pred_kc = x.predict(X_test_kc) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("KNeighborsClassifier model accuracy(in %):", metrics.accuracy_score(y_test_kc, y_pred_kc)*100)
# Out:
# KNeighborsClassifier model accuracy(in %): 90.41636319495024

# %%
print(classification_report(y_test_kc,y_pred_kc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     14601
#            1       0.60      0.49      0.54      1875
#
#     accuracy                           0.90     16476
#    macro avg       0.77      0.72      0.74     16476
# weighted avg       0.90      0.90      0.90     16476

# %% [markdown]
# ## SVC

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_svc, X_test_svc, y_train_svc, y_test_svc = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.svm import SVC
x = SVC(kernel = 'linear') 
x.fit(X_train_svc, y_train_svc) 

# making predictions on the testing set 
y_pred_svc = x.predict(X_test_svc) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("SVC model accuracy(in %):", metrics.accuracy_score(y_test_svc, y_pred_svc)*100)
# Out:
# SVC model accuracy(in %): 89.8458363680505

# %%
print(classification_report(y_test_svc,y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     14601
#            1       0.56      0.49      0.52      1875
#
#     accuracy                           0.90     16476
#    macro avg       0.75      0.72      0.73     16476
# weighted avg       0.89      0.90      0.90     16476

# %% [markdown]
# ## DecisionTreeClassifier

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_dtc, X_test_dtc, y_train_dtc, y_test_dtc = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.tree import DecisionTreeClassifier
x = DecisionTreeClassifier(criterion = 'gini') 
x.fit(X_train_dtc, y_train_dtc) 

# making predictions on the testing set 
y_pred_dtc = x.predict(X_test_dtc) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("DecisionTreeClassifier model accuracy(in %):", metrics.accuracy_score(y_test_dtc, y_pred_dtc)*100)
# Out:
# DecisionTreeClassifier model accuracy(in %): 88.80796309783928

# %%
print(classification_report(y_test_dtc,y_pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94     14601
#            1       0.51      0.52      0.51      1875
#
#     accuracy                           0.89     16476
#    macro avg       0.72      0.73      0.72     16476
# weighted avg       0.89      0.89      0.89     16476

# %% [markdown]
# ## RandomForestClassifier

# %% [markdown]
# How the data is imbamanced this is the best model for this kind of data:

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train_rfc, X_test_rfc, y_train_rfc, y_test_rfc = train_test_split(X, y, test_size=0.4, random_state=1) 

# training the model on training set 
from sklearn.ensemble import RandomForestClassifier
x = RandomForestClassifier(n_estimators=100, criterion = 'gini') # gini is better
x.fit(X_train_rfc, y_train_rfc) 

# making predictions on the testing set 
y_pred_rfc = x.predict(X_test_rfc) 

# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("RandomForestClassifier model accuracy(in %):", metrics.accuracy_score(y_test_rfc, y_pred_rfc)*100)
# Out:
# RandomForestClassifier model accuracy(in %): 91.54527798009225

# %%
print(classification_report(y_test_rfc,y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     14601
#            1       0.67      0.51      0.58      1875
#
#     accuracy                           0.92     16476
#    macro avg       0.80      0.74      0.77     16476
# weighted avg       0.91      0.92      0.91     16476

# %%
IDEAS:  
    
    predict if will be a top 20% client in balance having the rest of the data
    
    
  linearSVC puede ser un modelo interesante  
    
    subgroup: 
        
        ver default => deuda no pagada:  con balance, estudios, profesion y edad, calcular el dinero de un una persona
        ver balance => negativo: con studios, profesion y edad
        has personal loan or house => LOANS=== sma de los dos creditos
        grafic: educatio, job, singles VS married
    
    corr: 
        
        14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)

        15 - previous: number of contacts performed before this campaign and for this client (numeric)
   
  predecir:
        
        edad / profesion / educacion en funcion de balance
        
        cuando no va a default en funcion de balance?
        
        hacer reshape con el 10%  para ver si va a pagar el credit
        relacion entre eucacion y trabajo

# %%
DUDAS:
linspace??? LASSO??

ERRORES?? 

BIAS
Variance
Noise

sub-overfitting???

RMSE, MAR, R2??


sub/o
  Best profesi, mas dinero, estudiantes tienen mas dinero que el sector servicios.
Pre Processing
Sklearn provides a very efficient tool for encoding the levels of a categorical features into numeric values. LabelEncoder encode labels with value between 0 and n_classes-1

# %%
###StandardScaler?? collinear_features???

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Tools that I didn't use:

# %%
#EXTRA: other visualizations

   #data.plot(figsize=(12,6))
   #plt.style.use('classic')

   #sns.jointplot(x=data['age'], y=data['balance'], kind='kde', color='blue')
   
   #fig = plt.figure()
   #fig.suptitle('Algorithm Comparison')
   #ax = fig.add_subplot(111)
   #plt.boxplot(balance_loan.T)
   #ax.set_xticklabels(names)
